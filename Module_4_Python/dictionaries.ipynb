# %%
import os
cwd = os.getcwd()
print(cwd)
# Out:
# /home/user/generativeai/Python

# %%
allItems = os.listdir('.')
print(allItems)
# Out:
# ['os.ipynb', 'loops.ipynb', 'dictonaries.ipynb', 'dictionaries.ipynb', 'test.ipynb', 'functions.ipynb', 'standardLib.ipynb', 'sets.ipynb', 'exceptionHandling.ipynb']
# Bad pipe message: %s [b' 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/146.0.0.0 Sa']
# Bad pipe message: %s [b'ri/537.36\r\nAccept: text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,image/', b'ng,*/*;q=0.8\r\nAccept-Encoding: gzip, deflate, br, zstd\r\nAccept-Language: en-US,en;q=0.5\r\nPriorit']
# Bad pipe message: %s [b' u=0, i\r\nReferer: https://studio.firebase.google.com/\r\nSec-Ch-Ua: "Chromium";v="146", "Not-A.Brand";v="24", "Brave";v="1']
# Bad pipe message: %s [b'"\r\nSec-Ch-Ua-Arch: "x86"\r\nSec-Ch-Ua-Bitness: "64"\r\n']
# Bad pipe message: %s [b'c-Ch-Ua-Full-Version-List: "Chromium";v="146.0.0.0", "Not-A.Brand";v="24.0.0.0", "', b'ave";v="146.0.0.0"\r\nSec-Ch-Ua-Mobile: ?0\r\nSec-Ch-Ua-Model: ""\r\nSe']
# ...

# %%
folderName = "new folder"
fileName = "file.txt"
joinedPath = os.path.join(folderName,fileName)
print(joinedPath)
# Out:
# new folder/file.txt

# %%
currentFolderPath = "FileHandling"
currPath = os.getcwd()
currPath = currPath.split('\\')
currPath.pop()
currPath = '\\'.join(currPath)
print(currPath)

print(os.path.exists(os.path.join(currPath,currentFolderPath)))
# Out:
# False

# %%
currFile = 'example.txt'
print(os.path.isfile(currFile))

print(os.path.abspath(currFile))
# Out:
# False
# /home/user/generativeai/Python/example.txt

# %%
from math import *
print(int(sqrt(64)))
print(cos(67))
# Out:
# 8
# -0.5177697997895051
