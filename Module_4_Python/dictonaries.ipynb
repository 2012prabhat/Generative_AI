# %%
persons = {
    "name":"Prabhat Kumar",
    "age":28,
    "gender":"Male"
}

persons2 = persons
persons2["name"] = "Prabhat K"
print(persons.keys())
print(persons.values())
print(persons.items())


for key in persons:
    print(key,persons[key])
    
compObj = {x:x**2 for x in range(1,11)}
print(compObj)

evenDict = {x:x**2 for x in range(1,11) if x%2==0}
print(evenDict)
# Out:
# dict_keys(['name', 'age', 'gender'])
# dict_values(['Prabhat K', 28, 'Male'])
# dict_items([('name', 'Prabhat K'), ('age', 28), ('gender', 'Male')])
# name Prabhat K
# age 28
# gender Male
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
# {2: 4, 4: 16, 6: 36, 8: 64, 10: 100}

# %% [markdown]
# # Merge Dictionary

# %%
dict1 = {"a":1,"b":2,"c":3}
dict2 = {"a":1,"b":4,"c":5}
dict3 = {**dict1,**dict2}
print(dict3)
# Out:
# {'a': 1, 'b': 4, 'c': 5}
