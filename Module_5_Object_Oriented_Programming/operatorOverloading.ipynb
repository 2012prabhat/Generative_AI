# %%
class Avenger:
    def __init__(self,name,power):
        self.name = name
        self.power = power
        
    def __add__(self,other):
        return Avenger(self.name + ' & ' + other.name, self.power + other.power)
    
    def __str__(self):
        return f"{self.name} with power {self.power}"
    
    def __sub__(self,other):
        return Avenger(self.name,self.power - other.power)
    
ironMan = Avenger('Ironman',200)
hulk = Avenger('Hulk',300)

team = ironMan + hulk
print(team)
# Out:
# Ironman & Hulk with power 500
