# %%
class GrandParent:
    def __init__(self,name,locker_key):
        self.name = name
        self.__locker_key = locker_key

    def getLockerInfo(self):
        print(f'Locker Key: {self.__locker_key}')
        
child = GrandParent('Prabhat','12345')
child.getLockerInfo()
# Out:
# Locker Key: 12345
