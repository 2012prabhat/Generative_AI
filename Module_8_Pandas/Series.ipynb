# %%
import pandas as pd

pd.Series(data=[40,50,60],index=['Bread','Milk','Butter'],name='Price of grocery items')
data = pd.read_csv('youtube-top-100-songs-2025.csv')
dataframe = pd.read_csv('youtube-top-100-songs-2025.csv',index_col='title').squeeze('columns')
print(dataframe)
# print('Values of dataset',data.values)
# print('Index of dataset',data.index)
# Out:
#                                                                                             fulltitle  \
# title
# ROSÉ & Bruno Mars - APT. (Official Music Video)     ROSÉ & Bruno Mars - APT. (Official Music Video)
# Lady Gaga, Bruno Mars - Die With A Smile (Offic...  Lady Gaga, Bruno Mars - Die With A Smile (Offi...
# Reneé Rapp - Leave Me Alone (Official Music Video)  Reneé Rapp - Leave Me Alone (Official Music Vi...
# Billie Eilish - BIRDS OF A FEATHER (Official Mu...  Billie Eilish - BIRDS OF A FEATHER (Official M...
# Reneé Rapp - Mad (Official Music Video)                       Reneé Rapp - Mad (Official Music Video)
# ...                                                                                               ...
# Ariana Grande - twilight zone (Official Lyric V...  Ariana Grande - twilight zone (Official Lyric ...
# Gracie Abrams - I Love You, I’m Sorry (Official...  Gracie Abrams - I Love You, I’m Sorry (Officia...
# ...
